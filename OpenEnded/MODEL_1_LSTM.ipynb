# %%
import os
os.chdir(r'G:\8TH SEMESTER\MahaviaKhan_ML') 
from stlf_torch_kit import  DataLoadeing
import torch
import pandas as pd
import numpy as np
import pickle, time
from stlf_torch_kit import univariate_multi_step
from stlf_torch_kit import SaveBestModel, PlotLossCurves, LoadModel, train, TestModel, BatchGenerator, results
import torch.nn as nn
import torch.optim as optim
from torchinfo import summary

# %% [markdown]
# # Data Loading

# %%
import os
path_dataset ='G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\Dataset_CityLearn'
path_tr = os.path.join(path_dataset, 'CityLearn_train.csv')
df_tr = pd.read_csv(path_tr)
train_set = df_tr.iloc[:].values
path_v = os.path.join(path_dataset, 'CityLearn_validation.csv')
df_v = pd.read_csv(path_v)
validation_set = df_v.iloc[:].values 
path_te = os.path.join(path_dataset, 'Citylearn_test.csv')
df_te = pd.read_csv(path_te)
test_set = df_te.iloc[:].values 

path_scaler = os.path.join(path_dataset, 'Scaler.pkl')
scaler         = pickle.load(open(path_scaler, 'rb'))

train_set.shape, validation_set.shape, test_set.shape
# Out:
# ((6132, 29), (1752, 29), (876, 29))

# %%
time_steps = 24 
target_len = 1 #how much steps do you wana forecast #Edit
start = time.time()
train_X , train_y = univariate_multi_step(train_set, time_steps, target_col=0,target_len=target_len)
validation_X, validation_y = univariate_multi_step(validation_set, time_steps, target_col=0,target_len=target_len)
test_X, test_y = univariate_multi_step(test_set, time_steps, target_col=0,target_len=target_len)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Time Consumed 0.0810389518737793 sec

# %%
test_X.shape
# Out:
# (851, 24, 29)

# %% [markdown]
# #### LSTM_MODEL

# %%
class LSTMModel(nn.Module):
    def __init__(self, time_steps=24, num_features=29):
        super(LSTMModel, self).__init__()
        
        self.lstm1 = nn.LSTM(input_size=num_features, hidden_size=64, batch_first=True, dropout=0, bidirectional=False)
        self.dropout1 = nn.Dropout(0.3)

        self.lstm2 = nn.LSTM(input_size=64, hidden_size=32, batch_first=True, dropout=0, bidirectional=False)
        self.dropout2 = nn.Dropout(0.3)
        
        self.fc1 = nn.Linear(32, 16)
        self.relu = nn.ReLU()
        self.output_layer = nn.Linear(16, 1)

    def forward(self, x):
        # x shape: (batch_size, time_steps, num_features)
        x, _ = self.lstm1(x)
        x = self.dropout1(x)
        
        x, _ = self.lstm2(x)
        x = self.dropout2(x)
        
        # Only take the output of the last time step
        x = x[:, -1, :]  # shape: (batch_size, 32)
        
        x = self.fc1(x)
        x = self.relu(x)
        output = self.output_layer(x)
        
        return output

# %% [markdown]
# # instances

# %%
model = LSTMModel()#Edit
criterion = nn.MSELoss() #Edit, don't change

save_best_model = SaveBestModel()
Plot_Loss=PlotLossCurves()
load_model=LoadModel()

# %% [markdown]
# # Learning Rate & Optimizer

# %%
#lr=0.001 # Edit
#optimizer = torch.optim.Adam(model.parameters(), lr=lr) #Edit
lr = 0.001  # Initial learning rate
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=10, verbose=True)  # Added

# %% [markdown]
# # Check Device

# %%
def get_model_device(model):
    return next(model.parameters()).device
device = get_model_device(model)
print("Model is on device:", device)
# Out:
# Model is on device: cpu

# %% [markdown]
# # Training

# %% [markdown]
# #### Path & other Stuffs

# %%
start_epoch = 1
num_epochs = 50 #Edit
best_model_path=r'G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm'+str('\\') #Edit
fig_path=r'G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm' #Edit
train_data_loader, validation_data_loader, test_data_loader = DataLoadeing(train_X ,
                                                                           train_y, 
                                                                           validation_X, 
                                                                           validation_y, 
                                                                           test_X, 
                                                                           test_y, 
                                                                           batch_size=32) #Batch_Size Edit

# %% [markdown]
# #### Instances

# %%
criterion = nn.MSELoss() # Edit, for Now Don't  Change

criterion_mae = nn.L1Loss()

save_best_model = SaveBestModel()
Plot_Loss=PlotLossCurves()
load_model=LoadModel()

# %% [markdown]
# #### Training Loop

# %%
start = time.time()
train(start_epoch,
      num_epochs,
      best_model_path,
      fig_path,
      model,criterion,optimizer,save_best_model,Plot_Loss,
      train_data_loader,
      validation_data_loader)
print('Time Consumed', time.time()-start, "sec")
# Out:
# Epoch [1/50], Step [191/191], Training Loss: 0.0680
# Epoch [1/50], Step [54/54], Val Loss: 0.0398
#
# Saving best model for epoch: 1
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\1best_model.pth
# Epoch [2/50], Step [191/191], Training Loss: 0.0416
# Epoch [2/50], Step [54/54], Val Loss: 0.0399
# Epoch [3/50], Step [191/191], Training Loss: 0.0400
# Epoch [3/50], Step [54/54], Val Loss: 0.0395
#
# Saving best model for epoch: 3
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\3best_model.pth
# Epoch [4/50], Step [191/191], Training Loss: 0.0385
# Epoch [4/50], Step [54/54], Val Loss: 0.0396
# Epoch [5/50], Step [191/191], Training Loss: 0.0378
# Epoch [5/50], Step [54/54], Val Loss: 0.0395
#
# Saving best model for epoch: 5
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\5best_model.pth
# Epoch [6/50], Step [191/191], Training Loss: 0.0365
# Epoch [6/50], Step [54/54], Val Loss: 0.0392
#
# Saving best model for epoch: 6
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\6best_model.pth
# Epoch [7/50], Step [191/191], Training Loss: 0.0354
# Epoch [7/50], Step [54/54], Val Loss: 0.0391
#
# Saving best model for epoch: 7
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\7best_model.pth
# Epoch [8/50], Step [191/191], Training Loss: 0.0340
# Epoch [8/50], Step [54/54], Val Loss: 0.0389
#
# Saving best model for epoch: 8
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\8best_model.pth
# Epoch [9/50], Step [191/191], Training Loss: 0.0326
# Epoch [9/50], Step [54/54], Val Loss: 0.0393
# Epoch [10/50], Step [191/191], Training Loss: 0.0314
# Epoch [10/50], Step [54/54], Val Loss: 0.0389
#
# Saving best model for epoch: 10
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\10best_model.pth
# Epoch [11/50], Step [191/191], Training Loss: 0.0298
# Epoch [11/50], Step [54/54], Val Loss: 0.0380
#
# Saving best model for epoch: 11
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\11best_model.pth
# Epoch [12/50], Step [191/191], Training Loss: 0.0286
# Epoch [12/50], Step [54/54], Val Loss: 0.0361
#
# Saving best model for epoch: 12
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\12best_model.pth
# Epoch [13/50], Step [191/191], Training Loss: 0.0273
# Epoch [13/50], Step [54/54], Val Loss: 0.0350
#
# Saving best model for epoch: 13
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\13best_model.pth
# Epoch [14/50], Step [191/191], Training Loss: 0.0261
# Epoch [14/50], Step [54/54], Val Loss: 0.0340
#
# Saving best model for epoch: 14
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\14best_model.pth
# Epoch [15/50], Step [191/191], Training Loss: 0.0258
# Epoch [15/50], Step [54/54], Val Loss: 0.0326
#
# Saving best model for epoch: 15
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\15best_model.pth
# Epoch [16/50], Step [191/191], Training Loss: 0.0249
# Epoch [16/50], Step [54/54], Val Loss: 0.0315
#
# Saving best model for epoch: 16
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\16best_model.pth
# Epoch [17/50], Step [191/191], Training Loss: 0.0238
# Epoch [17/50], Step [54/54], Val Loss: 0.0318
# Epoch [18/50], Step [191/191], Training Loss: 0.0239
# Epoch [18/50], Step [54/54], Val Loss: 0.0301
#
# Saving best model for epoch: 18
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\18best_model.pth
# Epoch [19/50], Step [191/191], Training Loss: 0.0228
# Epoch [19/50], Step [54/54], Val Loss: 0.0309
# Epoch [20/50], Step [191/191], Training Loss: 0.0227
# Epoch [20/50], Step [54/54], Val Loss: 0.0300
#
# Saving best model for epoch: 20
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\20best_model.pth
# Epoch [21/50], Step [191/191], Training Loss: 0.0224
# Epoch [21/50], Step [54/54], Val Loss: 0.0300
#
# Saving best model for epoch: 21
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\21best_model.pth
# Epoch [22/50], Step [191/191], Training Loss: 0.0221
# Epoch [22/50], Step [54/54], Val Loss: 0.0297
#
# Saving best model for epoch: 22
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\22best_model.pth
# Epoch [23/50], Step [191/191], Training Loss: 0.0215
# Epoch [23/50], Step [54/54], Val Loss: 0.0297
#
# Saving best model for epoch: 23
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\23best_model.pth
# Epoch [24/50], Step [191/191], Training Loss: 0.0209
# Epoch [24/50], Step [54/54], Val Loss: 0.0291
#
# Saving best model for epoch: 24
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\24best_model.pth
# Epoch [25/50], Step [191/191], Training Loss: 0.0207
# Epoch [25/50], Step [54/54], Val Loss: 0.0293
# Epoch [26/50], Step [191/191], Training Loss: 0.0207
# Epoch [26/50], Step [54/54], Val Loss: 0.0291
#
# Saving best model for epoch: 26
#  at G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\26best_model.pth
# Epoch [27/50], Step [191/191], Training Loss: 0.0203
# Epoch [27/50], Step [54/54], Val Loss: 0.0299
# Epoch [28/50], Step [191/191], Training Loss: 0.0196
# Epoch [28/50], Step [54/54], Val Loss: 0.0304
# Epoch [29/50], Step [191/191], Training Loss: 0.0193
# Epoch [29/50], Step [54/54], Val Loss: 0.0299
# Epoch [30/50], Step [191/191], Training Loss: 0.0192
# Epoch [30/50], Step [54/54], Val Loss: 0.0304
# Epoch [31/50], Step [191/191], Training Loss: 0.0193
# Epoch [31/50], Step [54/54], Val Loss: 0.0305
# Epoch [32/50], Step [191/191], Training Loss: 0.0190
# Epoch [32/50], Step [54/54], Val Loss: 0.0309
# Epoch [33/50], Step [191/191], Training Loss: 0.0185
# Epoch [33/50], Step [54/54], Val Loss: 0.0312
# Epoch [34/50], Step [191/191], Training Loss: 0.0184
# Epoch [34/50], Step [54/54], Val Loss: 0.0309
# Epoch [35/50], Step [191/191], Training Loss: 0.0184
# Epoch [35/50], Step [54/54], Val Loss: 0.0325
# Epoch [36/50], Step [191/191], Training Loss: 0.0177
# Epoch [36/50], Step [54/54], Val Loss: 0.0335
# Epoch [37/50], Step [191/191], Training Loss: 0.0187
# Epoch [37/50], Step [54/54], Val Loss: 0.0345
# Epoch [38/50], Step [191/191], Training Loss: 0.0186
# Epoch [38/50], Step [54/54], Val Loss: 0.0336
# Epoch [39/50], Step [191/191], Training Loss: 0.0185
# Epoch [39/50], Step [54/54], Val Loss: 0.0329
# Epoch [40/50], Step [191/191], Training Loss: 0.0176
# Epoch [40/50], Step [54/54], Val Loss: 0.0343
# Epoch [41/50], Step [191/191], Training Loss: 0.0172
# Epoch [41/50], Step [54/54], Val Loss: 0.0339
# Epoch [42/50], Step [191/191], Training Loss: 0.0172
# Epoch [42/50], Step [54/54], Val Loss: 0.0359
# Epoch [43/50], Step [191/191], Training Loss: 0.0164
# Epoch [43/50], Step [54/54], Val Loss: 0.0368
# Epoch [44/50], Step [191/191], Training Loss: 0.0167
# Epoch [44/50], Step [54/54], Val Loss: 0.0347
# Epoch [45/50], Step [191/191], Training Loss: 0.0162
# Epoch [45/50], Step [54/54], Val Loss: 0.0353
# Epoch [46/50], Step [191/191], Training Loss: 0.0155
# Epoch [46/50], Step [54/54], Val Loss: 0.0348
# Epoch [47/50], Step [191/191], Training Loss: 0.0153
# Epoch [47/50], Step [54/54], Val Loss: 0.0331
# Epoch [48/50], Step [191/191], Training Loss: 0.0159
# Epoch [48/50], Step [54/54], Val Loss: 0.0336
# Epoch [49/50], Step [191/191], Training Loss: 0.0151
# Epoch [49/50], Step [54/54], Val Loss: 0.0348
# Epoch [50/50], Step [191/191], Training Loss: 0.0149
# Epoch [50/50], Step [54/54], Val Loss: 0.0343
# Time Consumed 561.7073912620544 sec

# %% [markdown]
# #### Results

# %%
load_model_path=r'G:\8TH SEMESTER\MahaviaKhan_ML\OpenEndedLab_0637\chk1_Lstm\26best_model.pth' # Edit
test_model=TestModel()
start = time.time()
y_pred_scaled=test_model(model, test_X,load_model,load_model_path,lr)
print('Time Consumed', time.time()-start, "sec")
results(scaler, y_pred_scaled,test_y)

# MAPE, MAE, RMSE
# Out:
# New lr = 0.001
# Time Consumed 0.48359179496765137 sec
# Mean Absolute Error (MAE): 0.38
# Median Absolute Error (MedAE): 0.28
# Mean Squared Error (MSE): 0.26
# Root Mean Squared Error (RMSE): 0.51
# Mean Absolute Percentage Error (MAPE): 57.63 %
# Median Absolute Percentage Error (MDAPE): 40.13 %
#
#
# y_test_unscaled.shape=  (851, 1)
# y_pred.shape=  (851, 1)
